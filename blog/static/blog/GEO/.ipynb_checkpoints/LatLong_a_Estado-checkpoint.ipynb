# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt
from shapely.geometry import Polygon, Point

# %%
df = pd.read_csv('poligonos_mx.csv') #Se lee el csv como un dataframe normal y después se convierte a geodataframe
df['geometry'] = df['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df, crs='epsg:4326')
gdf.head()
# Out:
#    Unnamed: 0 estado                                           geometry
# 0           0    ZAC  POLYGON ((-100.83230 24.55490, -100.85400 24.5...
# 1           1    YUC  POLYGON ((-87.53860 21.48640, -87.52560 21.287...
# 2           2    VER  POLYGON ((-97.79320 22.24960, -97.76810 22.049...
# 3           3    TLA  POLYGON ((-98.58490 19.46750, -98.63610 19.481...
# 4           4    TAM  POLYGON ((-97.79320 22.24960, -97.87290 22.197...

# %%
df_miso = pd.read_csv('GfG.csv')
df_miso.head()
# Out:
#    Index        Id                                               Post  \
# 0      1  emmanuel            Este post contiene mi ubicación exacta.
# 1      2      root  prueba de post con imagen de mapa de la Repúbl...
# 2      3  emmanuel  Nuevo post con mi ubicación exacta, éste post ...
# 3      4  emmanuel                                               XDDD
#
#                       Fecha    Latitud   Longitud
# 0  Aug. 30, 2021, 7:30 p.m.  21.003098 -89.635415
# 1  Aug. 31, 2021, 1:07 a.m.  20.985750 -89.521441
# 2  Sept. 6, 2021, 5:56 a.m.  20.968147 -89.629872
# 3   Oct. 5, 2021, 5:05 a.m.   0.000000   0.000000

# %%
columnas = ['Id','Post','Fecha','Latitud','Longitud','Estado']
df_miso_estado = pd.DataFrame(columns = columnas)
df_miso_estado.head()
# Out:
# Empty DataFrame
# Columns: [Id, Post, Fecha, Latitud, Longitud, Estado]
# Index: []

# %%
def dime_estado(lon, lat):
    estado = 'Fuera de México'
    band = 0
    point = Point(lon, lat)
    for index, row in gdf.iterrows():
        poligon = gdf['geometry'][index]
        if poligon.contains(point):
            estado = gdf['estado'][index]
            band = 1
            break
    return estado

# %%
for index, row in df_miso.iterrows():
    ide = row['Id']
    post = row['Post']
    datetime = row['Fecha']
    lat = row['Latitud']
    lon = row['Longitud']
    estado = dime_estado(lon, lat)
    df_miso_estado = df_miso_estado.append({'Id':ide,'Post':post,'Fecha':datetime,'Latitud':lat,'Longitud':lon,'Estado':estado}, ignore_index=True)

# %%
df_miso_estado.head()
# Out:
#          Id                                               Post  \
# 0  emmanuel            Este post contiene mi ubicación exacta.
# 1      root  prueba de post con imagen de mapa de la Repúbl...
# 2  emmanuel  Nuevo post con mi ubicación exacta, éste post ...
# 3  emmanuel                                               XDDD
# 4  emmanuel            Este post contiene mi ubicación exacta.
#
#                       Fecha    Latitud   Longitud           Estado
# 0  Aug. 30, 2021, 7:30 p.m.  21.003098 -89.635415              YUC
# 1  Aug. 31, 2021, 1:07 a.m.  20.985750 -89.521441              YUC
# 2  Sept. 6, 2021, 5:56 a.m.  20.968147 -89.629872              YUC
# 3   Oct. 5, 2021, 5:05 a.m.   0.000000   0.000000  Fuera de México
# 4  Aug. 30, 2021, 7:30 p.m.  21.003098 -89.635415              YUC

# %%
df_miso_estado.tail()
# Out:
#          Id                                               Post  \
# 3  emmanuel                                               XDDD
# 4  emmanuel            Este post contiene mi ubicación exacta.
# 5      root  prueba de post con imagen de mapa de la Repúbl...
# 6  emmanuel  Nuevo post con mi ubicación exacta, éste post ...
# 7  emmanuel                                               XDDD
#
#                       Fecha    Latitud   Longitud           Estado
# 3   Oct. 5, 2021, 5:05 a.m.   0.000000   0.000000  Fuera de México
# 4  Aug. 30, 2021, 7:30 p.m.  21.003098 -89.635415              YUC
# 5  Aug. 31, 2021, 1:07 a.m.  20.985750 -89.521441              YUC
# 6  Sept. 6, 2021, 5:56 a.m.  20.968147 -89.629872              YUC
# 7   Oct. 5, 2021, 5:05 a.m.   0.000000   0.000000  Fuera de México
